# %%
import pandas as pd
import numpy as np

# %%
filepath =".././data/2022-05-24 11.36.00/"
people_trips_df = pd.read_csv(filepath + 'people_trips_11_36_46.csv')
people_trips_df
# Out:
#      Cycle      Time  Traditional Scenario  Num Autonomous Bikes  \
# 0     1819  06:00:38                  True                     0
# 1     1952  06:05:04                  True                     0
# 2     2713  06:30:26                  True                     0
# 3     3154  06:45:08                  True                     0
# 4     3211  06:47:02                  True                     0
# ..     ...       ...                   ...                   ...
# 395  31515  22:30:30                  True                     0
# 396  31766  22:38:52                  True                     0
# 397  32248  22:54:56                  True                     0
# 398  33169  23:25:38                  True                     0
# 399  33191  23:26:22                  True                     0
#
#      Num Scooters  Num Conventional Bikes  Num Dockless Bikes      Agent  \
# 0               0                       0                  75    people0
# ...

# %%
dockless_trips_df = pd.read_csv(filepath + 'docklessBike_trip_event11_36_46.csv')
dockless_trips_df
# Out:
#       Cycle      Time  Traditional Scenario  Num Autonomous Bikes  \
# 0         0  05:00:00                  True                    75
# 1         0  05:00:00                  True                    75
# 2         0  05:00:00                  True                    75
# 3         0  05:00:00                  True                    75
# 4         0  05:00:00                  True                    75
# ...     ...       ...                   ...                   ...
# 2470  32976  23:19:12                  True                     0
# 2471  33157  23:25:14                  True                     0
# 2472  33158  23:25:16                  True                     0
# 2473  33167  23:25:34                  True                     0
# 2474  33168  23:25:36                  True                     0
#
#       Num Scooters  Num Conventional Bikes  Num Dockless Bikes  \
# 0                0                       0                  75
# ...

# %%
dockless_trips_df.dropna(inplace = True)
dockless_trips_df
# Out:
#       Cycle      Time  Traditional Scenario  Num Autonomous Bikes  \
# 75     1292  05:43:04                  True                     0
# 77     1318  05:43:56                  True                     0
# 79     1532  05:51:04                  True                     0
# 81     1641  05:54:42                  True                     0
# 83     1817  06:00:34                  True                     0
# ...     ...       ...                   ...                   ...
# 2465  32924  23:17:28                  True                     0
# 2467  32942  23:18:04                  True                     0
# 2469  32975  23:19:10                  True                     0
# 2471  33157  23:25:14                  True                     0
# 2473  33167  23:25:34                  True                     0
#
#       Num Scooters  Num Conventional Bikes  Num Dockless Bikes  \
# 75               0                       0                  75
# ...
